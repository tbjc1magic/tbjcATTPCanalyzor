# %%
from Analyzor.DataFactory import DataFactory
from Analyzor import VertexAnalyzor
import pylab as plt
import matplotlib.path as mplPath
import seaborn as sns
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 20)

# %% [markdown]
# ## load the SQL database and also the map data

# %%
dp = DataFactory('data/SQL/10C/0085_0000.db','data/SQL/10C/ProtoMap.db')
dp.InitT3()
# Out:
# 0085_0000 initialization will take some time
# 0085_0000loading finished
# 0085_0000 begin processing
# 0085_0000 processing finished

# %% [markdown]
# ## use the raw data to create mesh signals

# %%
dp.InitMesh()
dp.mesh_df.loc[6].plot()

# %% [markdown]
# ## plot the raw vertex trace and its detected positions

# %%
image = dp.ConstructImage(7)
image = VertexAnalyzor.FilterBackground(image)
points,(xc,yc) = VertexAnalyzor.GetEventPositions(image,1)
plt.scatter(xc,yc,s=200,c='r')
